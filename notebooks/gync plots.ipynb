# %%
using GynC
using JLD
# Out:
# WARNING: Method definition describe(AbstractArray) in module StatsBase at /home/numerik/bzfsikor/.julia/v0.5/StatsBase/src/scalarstats.jl:573 overwritten in module DataFrames at /home/numerik/bzfsikor/.julia/v0.5/DataFrames/src/abstractdataframe/abstractdataframe.jl:407.
# WARNING: using Plots.density in module GynC conflicts with an existing identifier.

# %%
include("../scripts/gyncplots.jl");
# Out:
# WARNING: No working GUI backend found for matplotlib

# %%
@load "paperplots/1000iter1h.jld" m ms muni ws
# Out:
# 4-element Array{Symbol,1}:
#  :m
#  :ms
#  :muni
#  :ws

# %% [markdown]
# # Plots

# %%
pyplot(fmt=:png)
patient = 20
denskdebw = 0.06
trajalphauni=30
#trajspecies = 4
denscolor = :dodgerblue
postcolor = :orangered
datacolor = :orangered
@time p=paperplot(m, muni, ws)
# Out:
# 691.685460 seconds (59.86 M allocations: 2.354 GB, 3.53% gc time)
# <img src="data:image/png;base64,..." />

# %%
@show trajspecies
@show densspecies
# Out:
# trajspecies = 3
# densspecies = [31]
# 1-element Array{Int64,1}:
#  31

# %%
GynC.samplednames[[8,31]]
# Out:
# 2-element Array{String,1}:
#  "blood volume"
#  "transition rate constant from PrA2 to SeF1"

# %%
GynC.measuredspeciesname.([3,1])
# Out:
# 2-element Array{String,1}:
#  "Estradiol in blood"
#  "LH in blood"

# %%
ylimsdens=[(0,0.35)]
denskdebw=0.1
# Out:
# 0.1

# %%
patient=14
densspecies=[31]
trajspecies=3
ylimstraj=(0,600)
@time paperplot(m,muni,ws)
@time savefig("master1.pdf")
# Out:
# computing likelihood matrix (15544x1) (0.840858153 seconds)
# computing likelihood matrix (2648x1) (1.329273426 seconds)
# 484.549718 seconds (60.37 M allocations: 2.479 GB, 4.47% gc time)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fe9e1617ed0>)
# 1039.775418 seconds (25.53 M allocations: 844.262 MB, 0.75% gc time)

# %%
patient = 14
densspecies=[8]
trajspecies = 1

ylimstraj=(0,80)
paperplot(m,muni,ws)|>display
savefig("master2.pdf")
# Out:
# <img src="data:image/png;base64,..." />
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fe9a005dcd0>)

# %%
patient=13
densspecies=[8]
trajspecies=3

ylimstraj=(0,600)

paperplot(m,muni,ws)|> display
savefig("master3.pdf")
# Out:
# computing likelihood matrix (15544x1) (2.459126208 seconds)
# computing likelihood matrix (2648x1)
# <img src="data:image/png;base64,..." />
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fe9ded56ed0>)
#  (0.037891874 seconds)
