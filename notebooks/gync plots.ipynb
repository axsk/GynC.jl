# %%
using GynC
using JLD
# Out:
# WARNING: Method definition describe(AbstractArray) in module StatsBase at /home/numerik/bzfsikor/.julia/v0.5/StatsBase/src/scalarstats.jl:573 overwritten in module DataFrames at /home/numerik/bzfsikor/.julia/v0.5/DataFrames/src/abstractdataframe/abstractdataframe.jl:407.
# WARNING: using Plots.density in module GynC conflicts with an existing identifier.

# %%
include("../scripts/gyncplots.jl");
# Out:
# WARNING: No working GUI backend found for matplotlib

# %%
@load "paperplots/1000iter1h.jld" m ms muni ws
# Out:
# 4-element Array{Symbol,1}:
#  :m
#  :ms
#  :muni
#  :ws

# %% [markdown]
# # Plots

# %%
pyplot(fmt=:png, grid=false)
patient = 20
denskdebw = 0.06
trajalphauni=30
#trajspecies = 4
denscolor = :dodgerblue
postcolor = :orangered
datacolor = :orangered
@time p=paperplot(m, muni, ws)
# Out:
# computing likelihood matrix (15544x1) (3.321341017 seconds)
# WARNING: the no-op `transpose` for non-numeric arrays is deprecated, and no specific `transpose` method for ColorTypes.RGB{Float64} exists. Use `permutedims(x, (2, 1))` for matrices and `reshape(x, 1, length(x))` for vectors, or write a specific `transpose(x::ColorTypes.RGB{Float64})` method if appropriate.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in transpose(::ColorTypes.RGB{Float64}) at ./deprecated.jl:771
#  in ctranspose at ./operators.jl:315 [inlined]
#  in (::Base.##209#210)(::Tuple{Int64,ColorTypes.RGB{Float64}}) at ./<missing>:0
#  in copy!(::Array{ColorTypes.RGB{Float64},2}, ::Base.Generator{Base.Prod2{Base.OneTo{Int64},Array{ColorTypes.RGB{Float64},1}},Base.##209#210}) at ./abstractarray.jl:485
#  in _collect(::Type{ColorTypes.RGB{Float64}}, ::Base.Generator{Base.Prod2{Base.OneTo{Int64},Array{ColorTypes.RGB{Float64},1}},Base.##209#210}, ::Base.HasShape) at ./array.jl:251
#  in ctranspose(::Array{ColorTypes.RGB{Float64},1}) at ./arraymath.jl:460
#  in #plotkdeiters#21(::Array{Any,1}, ::Function, ::Array{Float64,1}, ::Array{Array{Float64,1},1}) at /nfs/numerik/bzfsikor/dev/gc/scripts/gyncplots.jl:144
#  in (::#kw##plotkdeiters)(::Array{Any,1}, ::#plotkdeiters, ::Array{Float64,1}, ::Array{Array{Float64,1},1}) at ./<missing>:0
#  in macro expansion at /nfs/numerik/bzfsikor/dev/gc/scripts/gyncplots.jl:124 [inlined]
#  in (::##17#19{Array{Array{Float64,1},1},GynC.LikelihoodModel,Array{Float64,1}})(::Tuple{Int64,Int64}) at /nfs/numerik/bzfsikor/dev/gc/scripts/gyncplots.jl:122
#  in collect(::Base.Generator{Enumerate{Array{Int64,1}},##17#19{Array{Array{Float64,1},1},GynC.LikelihoodModel,Array{Float64,1}}}) at ./array.jl:307
#  in plotrow(::Array{Array{Float64,1},1}, ::GynC.LikelihoodModel) at /nfs/numerik/bzfsikor/dev/gc/scripts/gyncplots.jl:121
#  in #paperplot#14(::Array{Any,1}, ::Function, ::GynC.LikelihoodModel, ::GynC.LikelihoodModel, ::Dict{Any,Any}) at /nfs/numerik/bzfsikor/dev/gc/scripts/gyncplots.jl:100
#  in paperplot(::GynC.LikelihoodModel, ::GynC.LikelihoodModel, ::Dict{Any,Any}) at /nfs/numerik/bzfsikor/dev/gc/scripts/gyncplots.jl:99
#  in include_string(::String, ::String) at ./loading.jl:441
#  in execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/numerik/bzfsikor/.julia/v0.5/IJulia/src/execute_request.jl:156
#  in eventloop(::ZMQ.Socket) at /home/numerik/bzfsikor/.julia/v0.5/IJulia/src/eventloop.jl:8
#  in (::IJulia.##13#19)() at ./task.jl:360
# while loading In[13], in expression starting on line 188
# computing likelihood matrix (2648x1) (0.238769435 seconds)
# 112.381273 seconds (90.25 M allocations: 5.001 GB, 9.75% gc time)
# <img src="data:image/png;base64,..." />

# %%
@show trajspecies
@show densspecies
# Out:
# trajspecies = 3
# densspecies = [31]
# 1-element Array{Int64,1}:
#  31

# %%
GynC.samplednames[[8,31]]
# Out:
# 2-element Array{String,1}:
#  "blood volume"
#  "transition rate constant from PrA2 to SeF1"

# %%
GynC.measuredspeciesname.([3,1])
# Out:
# 2-element Array{String,1}:
#  "Estradiol in blood"
#  "LH in blood"

# %%
ylimsdens=[(0,0.35)]
denskdebw=0.1
# Out:
# 0.1

# %%
alphalim = 0
patient=14
densspecies=[31]
trajspecies=3
ylimstraj=(0,600)
@time p=paperplot(m,muni,ws)
@time savefig("master1.pdf")
# Out:
# 324.166713 seconds (46.12 M allocations: 1.849 GB, 3.59% gc time)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f57079b37d0>)
# 805.517371 seconds (19.68 M allocations: 652.809 MB, 0.58% gc time)

# %%
patient = 14
densspecies=[8]
trajspecies = 1

ylimstraj=(0,80)
paperplot(m,muni,ws)|>display
savefig("master2.pdf")
# Out:
# <img src="data:image/png;base64,..." />
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f56dbc6a390>)

# %%
patient=13
densspecies=[8]
trajspecies=3

ylimstraj=(0,600)

paperplot(m,muni,ws)|> display
savefig("master3.pdf")
# Out:
# InterruptException:
#
#  in _update_axis(::Plots.Axis, ::Dict{Symbol,Any}, ::Symbol, ::Int64) at /home/numerik/bzfsikor/.julia/v0.5/Plots/src/args.jl:1111
#  in _update_axis(::Plots.Plot{Plots.PyPlotBackend}, ::Plots.Subplot{Plots.PyPlotBackend}, ::Dict{Symbol,Any}, ::Symbol, ::Int64) at /home/numerik/bzfsikor/.julia/v0.5/Plots/src/args.jl:1093
#  in _update_subplot_args(::Plots.Plot{Plots.PyPlotBackend}, ::Plots.Subplot{Plots.PyPlotBackend}, ::Dict{Symbol,Any}, ::Int64, ::Bool) at /home/numerik/bzfsikor/.julia/v0.5/Plots/src/args.jl:1166
#  in _prepare_subplot(::Plots.Plot{Plots.PyPlotBackend}, ::Dict{Symbol,Any}) at /home/numerik/bzfsikor/.julia/v0.5/Plots/src/pipeline.jl:311
#  in _process_seriesrecipe(::Plots.Plot{Plots.PyPlotBackend}, ::Dict{Symbol,Any}) at /home/numerik/bzfsikor/.julia/v0.5/Plots/src/pipeline.jl:397
#  in _plot!(::Plots.Plot{Plots.PyPlotBackend}, ::Dict{Symbol,Any}, ::Tuple{FloatRange{Float64},Array{Float64,2}}) at /home/numerik/bzfsikor/.julia/v0.5/Plots/src/plot.jl:227
#  in #plot#263(::Array{Any,1}, ::Function, ::FloatRange{Float64}, ::Vararg{Any,N}) at /home/numerik/bzfsikor/.julia/v0.5/Plots/src/plot.jl:52
#  in (::Plots.#kw##plot)(::Array{Any,1}, ::Plots.#plot, ::FloatRange{Float64}, ::Array{Float64,2}, ::Vararg{Array{Float64,2},N}) at ./<missing>:0
#  in #plottrajdens#25(::Array{Float64,2}, ::Int64, ::Array{Any,1}, ::Function, ::Array{Array{Float64,1},1}, ::Array{Float64,1}) at /nfs/numerik/bzfsikor/dev/gc/scripts/gyncplots.jl:173
#  in (::#kw##plottrajdens)(::Array{Any,1}, ::#plottrajdens, ::Array{Array{Float64,1},1}, ::Array{Float64,1}) at ./<missing>:0
#  in plotrow(::Array{Any,1}, ::GynC.LikelihoodModel) at /nfs/numerik/bzfsikor/dev/gc/scripts/gyncplots.jl:133
#  in (::##15#16{Array{Any,1},GynC.LikelihoodModel,Dict{Any,Any}})(::String) at /nfs/numerik/bzfsikor/dev/gc/scripts/gyncplots.jl:108
#  in collect_to!(::Array{Array{Plots.Plot{Plots.PyPlotBackend},1},1}, ::Base.Generator{Array{String,1},##15#16{Array{Any,1},GynC.LikelihoodModel,Dict{Any,Any}}}, ::Int64, ::Int64) at ./array.jl:340
#  in collect_to_with_first!(::Array{Array{Plots.Plot{Plots.PyPlotBackend},1},1}, ::Array{Plots.Plot{Plots.PyPlotBackend},1}, ::Base.Generator{Array{String,1},##15#16{Array{Any,1},GynC.LikelihoodModel,Dict{Any,Any}}}, ::Int64) at ./array.jl:327
#  in _collect(::Array{String,1}, ::Base.Generator{Array{String,1},##15#16{Array{Any,1},GynC.LikelihoodModel,Dict{Any,Any}}}, ::Base.EltypeUnknown, ::Base.HasShape) at ./array.jl:321
#  in #paperplot#14(::Array{Any,1}, ::Function, ::GynC.LikelihoodModel, ::GynC.LikelihoodModel, ::Dict{Any,Any}) at /nfs/numerik/bzfsikor/dev/gc/scripts/gyncplots.jl:108
#  in paperplot(::GynC.LikelihoodModel, ::GynC.LikelihoodModel, ::Dict{Any,Any}) at /nfs/numerik/bzfsikor/dev/gc/scripts/gyncplots.jl:99
