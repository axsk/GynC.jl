# %%
using GynC, Plots, Distributions
gr(grid=false)
# Out:
# cookie: gjr5oNAlnbjfbosf
# WARNING: Method definition (::Type{Graphs.KeyVertex})(Int64, #K<:Any) in module Graphs at /home/numerik/bzfsikor/.julia/v0.5/Graphs/src/common.jl:12 overwritten at /home/numerik/bzfsikor/.julia/v0.5/Graphs/src/common.jl:16.
# WARNING: Method definition (::Type{Graphs.Edge})(Int64, #V<:Any, #V<:Any) in module Graphs at /home/numerik/bzfsikor/.julia/v0.5/Graphs/src/common.jl:54 overwritten at /home/numerik/bzfsikor/.julia/v0.5/Graphs/src/common.jl:60.
# WARNING: Method definition (::Type{Graphs.ExEdge})(Int64, #V<:Any, #V<:Any, Base.Dict{String, Any}) in module Graphs at /home/numerik/bzfsikor/.julia/v0.5/Graphs/src/common.jl:72 overwritten at /home/numerik/bzfsikor/.julia/v0.5/Graphs/src/common.jl:83.
# WARNING: Method definition (::Type{Graphs.TargetIterator})(#G<:Graphs.AbstractGraph, #EList<:Any) in module Graphs at /home/numerik/bzfsikor/.julia/v0.5/Graphs/src/common.jl:123 overwritten at /home/numerik/bzfsikor/.julia/v0.5/Graphs/src/common.jl:127.
# WARNING: Method definition (::Type{Graphs.SourceIterator})(#G<:Graphs.AbstractGraph, #EList<:Any) in module Graphs at /home/numerik/bzfsikor/.julia/v0.5/Graphs/src/common.jl:141 overwritten at /home/numerik/bzfsikor/.julia/v0.5/Graphs/src/common.jl:145.
# WARNING: Method definition edge_property_requirement(Graphs.AbstractEdgePropertyInspector{#T<:Any}, Graphs.AbstractGraph{#V<:Any, E<:Any}) in module Graphs at /home/numerik/bzfsikor/.julia/v0.5/Graphs/src/common.jl:164 overwritten at /home/numerik/bzfsikor/.julia/v0.5/Graphs/src/common.jl:179.
# WARNING: Method definition vertex_index(#V<:Union{Graphs.ExVertex, Graphs.KeyVertex}, Graphs.GenericGraph{#V<:Union{Graphs.ExVertex, Graphs.KeyVertex}, E<:Any, VList<:Any, EList<:Any, IncList<:Any}) in module Graphs at /home/numerik/bzfsikor/.julia/v0.5/Graphs/src/graph.jl:65 overwritten at /home/numerik/bzfsikor/.julia/v0.5/Graphs/src/graph.jl:67.
# WARNING: Method definition (::Type{Graphs.GDistanceVisitor})(#G<:Graphs.AbstractGraph, #DMap<:Any) in module Graphs at /home/numerik/bzfsikor/.julia/v0.5/Graphs/src/breadth_first_visit.jl:107 overwritten at /home/numerik/bzfsikor/.julia/v0.5/Graphs/src/breadth_first_visit.jl:111.
# VERSION: 0.5.0
# worker_arg: `--worker gjr5oNAlnbjfbosf`
# WARNING: using Plots.density in module GynC conflicts with an existing identifier.
# INFO: Recompiling stale cache file /home/numerik/bzfsikor/.julia/lib/v0.5/GR.ji for module GR.
# Plots.GRBackend()

# %%
xs = collect(1:1/3:50)
ts = [0.3, 1]
phi(k) = (GynC.Federn.odeohnetreatment(k))[1]
plot(xs, phi.(xs))
# Out:
# WARNING: odeohnetreatment(k) is deprecated, use odesol(k) instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in odeohnetreatment(::Float64) at ./deprecated.jl:50
#  in phi(::Float64) at ./In[2]:2
#  in broadcast_t(::Function, ::Type{Any}, ::Array{Float64,1}, ::Vararg{Array{Float64,1},N}) at ./broadcast.jl:222
#  in broadcast(::Function, ::Array{Float64,1}) at ./broadcast.jl:230
#  in include_string(::String, ::String) at ./loading.jl:441
#  in execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/numerik/bzfsikor/.julia/v0.5/IJulia/src/execute_request.jl:157
#  in eventloop(::ZMQ.Socket) at /home/numerik/bzfsikor/.julia/v0.5/IJulia/src/eventloop.jl:8
#  in (::IJulia.##13#19)() at ./task.jl:360
# while loading In[2], in expression starting on line 3
# WARNING: odeohnetreatment(k) is deprecated, use odesol(k) instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  
#   373.357,371.951 377.264,369.37 381.171,366.582 385.078,363.594 388.985,360.412 392.892,357.043 396.799,353.494 400.706,349.772 404.614,345.884 408.521,341.836
#   412.428,337.637 416.335,333.293 420.242,328.811 424.149,324.2 428.056,319.465 431.964,314.614 435.871,309.652 439.778,304.587 443.685,299.426 447.592,294.175
#   451.499,288.842 455.406,283.434 459.313,277.957 463.221,272.418 467.128,266.822 471.035,261.178 474.942,255.489 478.849,249.763 482.756,244.006 486.663,238.224
#   490.57,232.423 494.478,226.609 498.385,220.787 502.292,214.964 506.199,209.145 510.106,203.335 514.013,197.539 517.92,191.762 521.828,186.01 525.735,180.288
#   529.642,174.6 533.549,168.951 537.456,163.345 541.363,157.788 545.27,152.283 549.177,146.835 553.085,141.447 556.992,136.124 560.899,130.87 564.806,125.688
#   568.713,120.581 572.62,115.553 576.527,110.608 580.434,105.748 584.342,100.978 588.249,96.3001 592.156,91.7164 596.063,87.2299
#   "/>
# <polygon clip-path="url(#clip00)" points="
# 505.547,55.057 578.063,55.057 578.063,24.817 505.547,24.817
#   " fill="#ffffff" fill-opacity="1"/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   505.547,55.057 578.063,55.057 578.063,24.817 505.547,24.817 505.547,55.057
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#0099ff; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   511.547,39.937 547.547,39.937
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 553.547, 44.437)" x="553.547" y="44.437">y1</text>
# </g>
# </svg>

# %%
measerr = Normal(0,1)
ndata = 300
augz = 200
prior = GynC.Federn.prior

srand(1)
m = GynC.syntheticmodel(xs, phi, prior, ndata, augz, measerr)

augd = 200
@show stdd = KernelDensity.default_bandwidth(m.datas)
ms = GynC.smoothdata(m, augd, stdd);
# Out:
# stdd = KernelDensity.default_bandwidth(m.datas) = 1.500700681666547
# UndefVarError: smoothdata not defined

# %%
w0 = ones(length(xs)) / length(xs);

#w0 = pdf(Distributions.Beta(3,3), xs/50)
#w0 = w0 / sum(w0)

wprior = pdf(prior, xs)
wprior = wprior / sum(wprior);

# %%
niter = 500
h = 0.1

ws = Dict()
@time ws["NPMLE"] = GynC.em(m, w0, niter)
@time ws["DS-MLE"] = GynC.em(ms, w0, niter);
@time ws["MPLE"]  = GynC.mple(m, w0, niter, .98, h)
@time ws["Reference Prior"] = GynC.mple(m, w0, niter, 1, h);
# Out:
# computing likelihood matrix (148x300)
# type Normal has no field sigmas
#
#  in collect(::Base.Generator{Array{Float64,1},GynC.##107#109{Distributions.Normal{Float64}}}) at ./array.jl:307
#  in likelihoodmat_nanfast(::Array{Float64,1}, ::Array{Float64,1}, ::Distributions.Normal{Float64}) at /home/numerik/bzfsikor/.julia/v0.5/GynC/src/eb/likelihoodmat.jl:27
#  in macro expansion at ./util.jl:226 [inlined]
#  in likelihoodmat_unmemoized(::Array{Float64,1}, ::Array{Float64,1}, ::Distributions.Normal{Float64}) at /home/numerik/bzfsikor/.julia/v0.5/GynC/src/eb/likelihoodmat.jl:10
#  in likelihoodmat(::Array{Float64,1}, ::Array{Float64,1}, ::Distributions.Normal{Float64}) at /home/numerik/bzfsikor/.julia/v0.5/Memoize/src/Memoize.jl:103
#  in em(::GynC.LikelihoodModel, ::Array{Float64,1}, ::Int64) at /home/numerik/bzfsikor/.julia/v0.5/GynC/src/eb/likelihoodmodel.jl:18

# %%
labels = ["NPMLE" "DS-MLE" "Reference Prior" "MPLE"]
densities = map(l->ws[l][end], labels) |> vec

plot(xs, wprior, label="True Prior", linewidth=2, legendfont=font(10), tickfont=font(8), ylims=(0,0.05), size=(600, 350), grid=false)
plot!(xs, densities, labels=labels, linewidth=1.2)
# Out:
# KeyError: key "NPMLE" not found
#
#  in getindex(::Dict{Any,Any}, ::String) at ./dict.jl:688
#  in #1 at ./In[6]:2 [inlined]
#  in next at ./generator.jl:26 [inlined]
#  in _collect(::Array{String,2}, ::Base.Generator{Array{String,2},##1#2}, ::Base.EltypeUnknown, ::Base.HasShape) at ./array.jl:320
#  in map(::Function, ::Array{String,2}) at ./abstractarray.jl:1683

# %%
function weightedquantile(ys, w; quantiles=collect(1/8:1/8:7/8))
  sp = sortperm(ys)
  cs = cumsum(w[sp])
  mx = cs[end]
  quantileinds = [findfirst(x->x>=q, cs) for q = mx*quantiles]
  ys[sp[quantileinds]]
end

function calcquantiles(ts, sols, w;quantiles = collect(1/10:1/10:9/10))
  res = Matrix(length(ts), length(quantiles))
  for t in 1:length(ts)
      res[t,:] = weightedquantile([sols[x][t] for x in 1:length(xs)], w, quantiles = quantiles)
  end
  res
end

function plotquantiles(ts, sols, w)
    
  res = calcquantiles(ts, sols, w)
  n = size(res,2)
  p = plot()
  mid = Int((n+1)/2)
  offsets = Int((n-1)/2):-1:0 
  for o in offsets
    plot!(ts, res[:,mid-o], fillrange=res[:,mid+o])
  end
  p
end

function bayesposterior(m, data, wprior)
    L = likelihoodmat(m.ys, data, m.measerr)
    GynC.emiteration(wprior, L)
end

kdenpoints = 300

function plottrajdens(ts, sols, w)

  msol = hcat(sols...)
  mkde = hcat([KernelDensity.kde(msol[t,:], boundary = (-13,13), weights=w, bandwidth = 0.5, npoints=kdenpoints).density for t in 1:size(msol, 1)]...)

  contour(ts, linspace(-13,13, kdenpoints), mkde, clims=(1e-5,0.3), fill=true, seriescolor = :heat, legend=false)
end
# Out:
# plottrajdens (generic function with 1 method)

# %%
ts = 0:1/100:2
sols = [GynC.Federn.odesol(k,ts) for k = xs];
plotquantiles(ts, sols, w0)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 30.6037,384.952 596.063,384.952 596.063,3.93701 30.6037,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="30" y="3" width="566" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 596.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 30.6037,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   171.969,384.952 171.969,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   313.333,384.952 313.333,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   454.698,384.952 454.698,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   596.063,384.952 596.063,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 30.6037,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 39.0856,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,289.531 39.0856,289.531
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,194.111 39.0856,194.111
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,98.6903 39.0856,98.6903
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 30.6037, 396.952)" x="30.6037" y="396.952">0.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 171.969, 396.952)" x="171.969" y="396.952">0.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 313.333, 396.952)" x="313.333" y="396.952">1.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 454.698, 396.952)" x="454.698" y="396.952">1.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 596.063, 396.952)" x="596.063" y="396.952">2.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 389.452)" x="29.4037" y="389.452">-10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 294.031)" x="29.4037" y="294.031">-5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 198.611)" x="29.4037" y="198.611">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 103.19)" x="29.4037" y="103.19">5</text>
# </g>
# <polygon clip-path="url(#clip02)" points="
# 30.6037,384.952 33.431,384.875 36.2583,384.643 39.0856,384.257 41.9129,383.717 44.7402,383.023 47.5675,382.177 50.3948,381.179 53.222,380.029 56.0493,378.729
#   58.8766,377.279 61.7039,375.681 64.5312,373.935 67.3585,372.044 70.1858,370.009 73.0131,367.832 75.8404,365.515 78.6677,363.059 81.495,360.467 84.3223,357.739
#   87.1496,354.878 89.9769,351.887 92.8042,348.768 95.6315,345.524 98.4588,342.158 101.286,338.673 104.113,335.071 106.941,331.355 109.768,327.527 112.595,323.592
#   596.063,371.522 596.063,8.69575 593.236,8.40598 590.408,8.59001 587.581,7.38922 584.754,8.48208 581.927,7.61429 579.099,8.25062 576.272,7.80428

# %%
function plotcol(w)
    ts = 0:1/100:2
    sols = [GynC.Federn.odesol(k,ts) for k = xs]
    meas = [2]
    
    
    ylims = (0,0.1)
    yscale = length(xs) / maximum(xs)
    
    local pprior
    if isa(w[1], Vector)
        pprior = plot(xs, w*yscale, legend=false, seriescolor= collect(colormap("blues", length(w)))', ylims=ylims)
        w = w[end]
    else
        pprior = plot(xs, w*yscale, legend=false, color="black", ylims=ylims)
    end
    
    wpost = bayesposterior(m, meas, w)
    
    plot!(xs, wpost*yscale, color=:dodgerblue)
    
    
    pprioq = plottrajdens(ts, sols, w)
    scatter!(pprioq, repmat([1], length(m.datas)), m.datas, alpha = 0.2, markerstrokewidth = 0, marker=:hline, color=:black)
    
    ppostq = plottrajdens(ts, sols, wpost)
    scatter!(ppostq, [1], meas, marker=:hline, color=:dodgerblue, ms=6)
    [pprior, pprioq, ppostq]
end

#plot(plotcol(ws["NPMLE"])..., size=(1000,400), layout=(1,3))
# Out:
# plotcol (generic function with 1 method)

# %%
aplots = hcat(plotcol(wprior), plotcol(w0), plotcol(ws["NPMLE"][end]), plotcol(ws["DS-MLE"][end]), plotcol(ws["MPLE"][end]))
plot(aplots..., size=(1200,900), layout=(5,3))
# Out:
# computing likelihood matrix (148x1)
# type Normal has no field sigmas
#
#  in collect(::Base.Generator{Array{Float64,1},GynC.##107#109{Distributions.Normal{Float64}}}) at ./array.jl:307
#  in likelihoodmat_nanfast(::Array{Float64,1}, ::Array{Int64,1}, ::Distributions.Normal{Float64}) at /home/numerik/bzfsikor/.julia/v0.5/GynC/src/eb/likelihoodmat.jl:27
#  in macro expansion at ./util.jl:226 [inlined]
#  in likelihoodmat_unmemoized(::Array{Float64,1}, ::Array{Int64,1}, ::Distributions.Normal{Float64}) at /home/numerik/bzfsikor/.julia/v0.5/GynC/src/eb/likelihoodmat.jl:10
#  in likelihoodmat(::Array{Float64,1}, ::Array{Int64,1}, ::Distributions.Normal{Float64}) at /home/numerik/bzfsikor/.julia/v0.5/Memoize/src/Memoize.jl:103
#  in bayesposterior at ./In[7]:31 [inlined]
#  in plotcol(::Array{Float64,1}) at ./In[9]:18

# %%
savefig("paper federn.pdf")

# %%
for (k,w) in ws
    plot(plot(map(w->GynC.hz(m,w), w)), plot(map(w->GynC.logl(m,w), w)), title=k) |> display
end

# %%
r(x) = GynC.Federn.maxtreatamplitude(x) > 13 ? 1 : 0

rxs = r.(xs)

R(w, data) = dot(bayesposterior(m, data, w), rxs)

stdR(w) = sqrt(1/(length(m.datas)-1) * sumabs2((R(w, data) - R(wprior, data)) for data in m.datas))

map(stdR, [w0, ws["NPMLE"][end], ws["DS-MLE"][end], ws["MPLE"][end]])
# Out:
# KeyError: key "NPMLE" not found
#
#  in getindex(::Dict{Any,Any}, ::String) at ./dict.jl:688
