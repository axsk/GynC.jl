# %%
using Plots
@time include("../src/federn/federn.jl");

# %%
#switch between peturbed and unperturbed Lzz versions

#Lzz = [rho_error(z-z2) for z in zs, z2 in zs] # unperturbed
#Lzz = [rho_error(z-z2) for z in zps, z2 in zs]  # perturbed

# %%
# define beta distribution prior, and get corresponding sampling weights
s = xmax+1
pi_0(x) = (x/s).*(1-x/s).^3.*(x/s.>0).*(x/s.<1)*20/s
betaw=map(pi_0, samples)
betaw=betaw/sum(betaw)

w0 = betaw

title = "EM-Iterations on pi0"
plot(samples, ws_em(betaw, 100), title=title)
# Out:
# WARNING: Method definition pi_0(Any) in module Main at In[3]:3 overwritten at In[21]:3.
# <img src="data:image/png;base64,..." />

# %%
# compare different zentropies
randw = rand(300)
randw = randw/sum(randw)
unitw = ones(300) / 300

@show zentropy(randw)
@show zentropy(unitw)
@show zentropy(betaw)
# Out:
# zentropy(randw) = 5.879060503048758
# zentropy(unitw) = 5.87116766617912
# zentropy(betaw) = 5.911035544384982
# 5.911035544384982

# %%
# dictionary for different weightings
wdict = Dict{String, Vector{Vector{Float64}}}()
niter = 50;

# %%
# gradientascent penalized max. likelihood
# with stepsize `h` and entropy weighting `s`
gapml(w0, niter, h=1, s=1) = gradientascent(x->pml(x,s), w0, niter, h, GynC.projectsimplex)

# %%
# em algorithm
wdict["em"]  = ws_em(w0, niter)

# penalized maximum lilkelihood with different stepsizes and entropy weights
wdict["pml e-7"] =     gapml(w0, niter, 0.0000001)
wdict["pml e-6"] =     gapml(w0, niter, 0.000001)
wdict["pml e-6 se1"] = gapml(w0, niter, 0.000001, 10)
wdict["pml e-6 se3"] = gapml(w0, niter, 0.000001, 1000)

# maximal likelihood (setting entropy weight to 0)
wdict["l   e-6  s0"] = gapml(w0, niter, 0.000001, 0)

# zentropy maximization
wdict["ze e-3"] = gradientascent(x->zentropy(x), w0, niter, 0.001, GynC.projectsimplex);

# %%
include("../src/optim3.jl")

zeplot = plot(yaxis="zentropy")
mlplot = plot(yaxis="marg. loglikel.")
hklplot = plot(yaxis="hkl")

for (key, ws) in wdict
    plot!(zeplot, map(zentropy, ws), label=key)
    plot!(mlplot, map(marginallikelihood, ws), label=key)
    plot!(hklplot, map(w->HKL(w,Lzz), ws), label=key)
end
plot(zeplot, mlplot, hklplot, size=(1000,600))
# Out:
# WARNING: Method definition HKL(Any, Any) in module Main at /nfs/numerik/bzfsikor/dev/gc/src/optim3.jl:5 overwritten at /nfs/numerik/bzfsikor/dev/gc/src/optim3.jl:5.
# WARNING: Method definition HKL(Any, Any, Any) in module Main at /nfs/numerik/bzfsikor/dev/gc/src/optim3.jl:5 overwritten at /nfs/numerik/bzfsikor/dev/gc/src/optim3.jl:5.
# <img src="data:image/png;base64,..." />

# %%
ww=wdict["ze e-3"]

# histogram in Z
function zplot(w; args...)
    zsmpls = sample(GynC.WeightedSampling(zs, w), 1000)
    histogram2d(map(x->x[1], zsmpls), map(x->x[2], zsmpls); args...)
end
plot([zplot(ww[i], title=i) for i=[1,5,20,50]]...)
# Out:
# WARNING: Method definition zplot(Any) in module Main at In[9]:4 overwritten at In[30]:4.
# WARNING: Method definition #zplot(Array{Any, 1}, Main.#zplot, Any) in module Main overwritten.
# <img src="data:image/png;base64,..." />

# %%
# plot iterations in x
function plotiters(ws; kwargs...)
    plot(samples,hcat(ws...), kwargs...)
end

plotiters(ww)
# Out:
# WARNING: Method definition plotiters(Any) in module Main at In[10]:2 overwritten at In[31]:2.
# WARNING: Method definition #plotiters(Array{Any, 1}, Main.#plotiters, Any) in module Main overwritten.
# <img src="data:image/png;base64,..." />

# %%
# unperturbed z samples
temp = hcat(zs...)
p1 = scatter(temp[1,:],temp[2,:])
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 34.5407,381.015 596.063,381.015 596.063,3.93701 34.5407,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="34" y="3" width="562" height="378"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   50.4271,375.359 50.4271,9.59318
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   315.301,375.359 315.301,9.59318
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   580.174,375.359 580.174,9.59318
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9635,370.352 587.64,370.352
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9635,192.475 587.64,192.475
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9635,14.5978 587.64,14.5978
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   34.5407,381.015 596.063,381.015
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   50.4271,381.015 50.4271,375.359
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   315.301,381.015 315.301,375.359
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   580.174,381.015 580.174,375.359
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   34.5407,381.015 34.5407,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   34.5407,370.352 42.9635,370.352
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   34.5407,192.475 42.9635,192.475
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   34.5407,14.5978 42.9635,14.5978
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 50.4271, 393.015)" x="50.4271" y="393.015">-10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 315.301, 393.015)" x="315.301" y="393.015">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.174, 393.015)" x="580.174" y="393.015">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3407, 374.852)" x="33.3407" y="374.852">-10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3407, 196.975)" x="33.3407" y="196.975">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3407, 19.0978)" x="33.3407" y="19.0978">10</text>
# </g>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="412.454" cy="271.617" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="412.454" cy="271.617" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="361.314" cy="320.414" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="361.314" cy="320.414" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="315.07" cy="351.084" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="315.07" cy="351.084" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="273.459" cy="366.751" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="273.459" cy="366.751" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="236.226" cy="370.179" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="236.226" cy="370.179" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="203.126" cy="363.803" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="203.126" cy="363.803" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="173.921" cy="349.76" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="173.921" cy="349.76" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="148.387" cy="329.914" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="148.387" cy="329.914" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="126.302" cy="305.879" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="126.302" cy="305.879" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="107.461" cy="279.05" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="107.461" cy="279.05" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="91.6584" cy="250.616" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="91.6584" cy="250.616" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="78.7119" cy="221.585" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="78.7119" cy="221.585" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="68.4213" cy="192.801" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="68.4213" cy="192.801" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="60.6147" cy="164.961" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="60.6147" cy="164.961" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="55.1332" cy="138.632" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="55.1332" cy="138.632" r="2"/>
# <c

# %%
# perturbed z samples (1 z- per 1 x-sample)
temp = hcat(zps...)
scatter(temp[1,:],temp[2,:])
# Out:
# <img src="data:image/png;base64,..." />

# %%
# generate multiple, perturbed z-meas. per x 

nerrspl = 200 # n error samples

ntimes(w,n) = repeat(w, inner=[n]) / n
ntimespert(zs, n) = map(x -> x+randn(2) * rho_std, ntimes(zs, n));

# adapt the Lzz matrix
Lzzbig = [rho_error(z-zp) for zp in ntimespert(zs, nerrspl), z in zs];
# Out:
# WARNING: Method definition ntimes(Any, Any) in module Main at In[166]:5 overwritten at In[168]:5.
# WARNING: Method definition ntimespert(Any, Any) in module Main at In[166]:6 overwritten at In[168]:6.

# %%
# "kullbach leibler entropy"
include("../src/optim3.jl")
gahkl(w0, niter, h=1, s=1) = gradientascent(w->HKL(w, Lzzbig, ntimes(w, nerrspl)), w0, niter, h, GynC.projectsimplex)

@time hkl = gahkl(w0, 10, 1e2);

push!(wdict, "hkl" => hkl)

# %%
plotiters(hkl)
# Out:
# <img src="data:image/png;base64,..." />

# %%
(hkl[end] .== 0) |> any
# Out:
# false

# %%
using KernelDensity

function priorpredictivekde(w)
  zsx = map(x->x[1], zs)
  zsy = map(x->x[2], zs)

  k=kde((zsx,zsy), weights = w, bandwidth=(5.,5.))
  k.x, k.y, k.density
end

function plot_priorpredictivedistr(w; kwargs...)
  contour(priorpredictivekde(w)..., title="Prior predictive distribution"; kwargs...)
end
# Out:
# WARNING: Method definition priorpredictivekde(Any) in module Main at In[140]:4 overwritten at In[200]:4.
# WARNING: Method definition plot_priorpredictivedistr(Any) in module Main at In[140]:12 overwritten at In[200]:12.
# WARNING: Method definition #plot_priorpredictivedistr(Array{Any, 1}, Main.#plot_priorpredictivedistr, Any) in module Main overwritten.
# plot_priorpredictivedistr (generic function with 1 method)

# %%
using Interact

@manipulate for x in wdict, a in 1:niter
  w=x[a]
  println(a)
  p2 = plot_priorpredictivedistr(w, clims=(0,0.002), levels=20, xlim=(-15, 15), ylim=(-15,15))
  p3 = plot(p1, xlim=(-15,15), ylim=(-15,15))
  plot(p2,p3,size=(1000,500))
end
# Out:
# Interact.Options{:ToggleButtons,Any}(Signal{Any}(Array{Float64,1}[[0.000576205,0.000778468,0.000976634,0.00117074,0.00136084,0.00154696,0.00172914,0.00190743,0.00208187,0.00225249,0.00241935,0.00258246,0.00274188,0.00289765,0.0030498,0.00319837,0.00334341,0.00348494,0.00362302,0.00375767,0.00388893,0.00401685,0.00414145,0.00426279,0.00438089,0.00449579,0.00460753,0.00471615,0.00482167,0.00492415,0.00502361,0.00512009,0.00521363,0.00530426,0.00539202,0.00547694,0.00555905,0.0056384,0.00571502,0.00578894,0.0058602,0.00592882,0.00599485,0.00605832,0.00611926,0.00617771,0.00623369,0.00628725,0.00633841,0.00638721,0.00643367,0.00647784,0.00651974,0.00655941,0.00659687,0.00663217,0.00666532,0.00669637,0.00672534,0.00675227,0.00677717,0.0068001,0.00682107,0.00684011,0.00685726,0.00687254,0.00688599,0.00689763,0.0069075,0.00691562,0.00692202,0.00692673,0.00692977,0.00693119,0.00693099,0.00692922,0.0069259,0.00692106,0.00691472,0.00690692,0.00689767,0.00688701,0.00687497,0.00686156,0.00684681,0.00683076,0.00681343,0.00679484,0.00677502,0.00675399,0.00673178,0.00670841,0.00668392,0.00665831,0.00663163,0.00660389,0.00657511,0.00654532,0.00651455,0.00648282,0.00645014,0.00641655,0.00638206,0.00634671,0.00631051,0.00627348,0.00623565,0.00619703,0.00615766,0.00611755,0.00607673,0.0060352,0.00599301,0.00595016,0.00590668,0.00586259,0.00581791,0.00577266,0.00572685,0.00568052,0.00563367,0.00558633,0.00553852,0.00549025,0.00544155,0.00539244,0.00534293,0.00529304,0.00524278,0.00519219,0.00514127,0.00509004,0.00503852,0.00498673,0.00493469,0.00488241,0.0048299,0.00477719,0.00472429,0.00467122,0.00461799,0.00456462,0.00451112,0.00445752,0.00440382,0.00435004,0.00429619,0.0042423,0.00418837,0.00413442,0.00408046,0.00402651,0.00397258,0.00391868,0.00386
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.9635,99.6537 390.64,99.6537
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.9635,23.3815 390.64,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   34.5407,481.015 396.063,481.015
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   34.5407,481.015 34.5407,474.15
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   94.7944,481.015 94.7944,474.15
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   155.048,481.015 155.048,474.15
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   215.302,481.015 215.302,474.15
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   275.556,481.015 275.556,474.15
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   335.809,481.015 335.809,474.15
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   396.063,481.015 396.063,474.15
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   34.5407,481.015 34.5407,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   34.5407,481.015 39.9635,481.015
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   34.5407,404.743 39.9635,404.743
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   34.5407,328.47 39.9635,328.47
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   34.5407,252.198 39.9635,252.198
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   34.5407,175.926 39.9635,175.926
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   34.5407,99.6537 39.9635,99.6537
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   34.5407,23.3815 39.9635,23.3815
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 34.5407, 493.815)" x="34.5407" y="493.815">-15</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 94.7944, 493.815)" x="94.7944" y="493.815">-10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 155.048, 493.815)" x="155.048" y="493.815">-5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 215.302, 493.815)" x="215.302" y="493.815">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 275.556, 493.815)" x="275.556" y="493.815">5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 335.809, 493.815)" x="335.809" y="493.815">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 396.063, 493.815)" x="396.063" y="493.815">15</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.5407, 485.515)" x="32.5407" y="485.515">-15</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.5407, 409.243)" x="32.5407" y="409.243">-10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rot

# %%
# compute the zentropy based on the kde instead of plain monte carlo integration
# i.e. on a regular grid, instead of the x samples
function zentropykde(w)
  h=0.
  kdew = priorpredictivekde(w)[3]
  kdew = kdew / sum(kdew)
  for d in kdew      
      h-=d*log(d)
  end
  h
end
# Out:
# WARNING: Method definition zentropykde(Any) in module Main at In[120]:2 overwritten at In[201]:2.
# zentropykde (generic function with 1 method)

# %%
w = wdict["ze e-3"][end]
map(zentropykde, [w0, w])

# zentropy on kde, decreasing :/
# Out:
# 2-element Array{Float64,1}:
#  10.2898
#  10.223

# %%
map(w->GynC.Hz(w, Lzzbig, ntimes(w, nerrspl)), [w0, w])

# zentropy on the with perturbed z samples
# Out:
# 2-element Array{Float64,1}:
#  11.0255
#  11.0377

# %%
# initialize error distribution
err = Distributions.MvNormal(2,5.)

# compute uniform z grid
zs_uniform = reshape([[x,y] for x in k.x, y in k.y], 256*256)

# compute likelihoods on grid
@time L_zuni_x = [pdf(err, z-z2) for z in zs_uniform, z2 in zs]

# compute rhozw on grid

function rhozw_f(w) 
    r = L_zuni_x * w
    r/sum(r)
end
# Out:
#  14.746670 seconds (137.66 M allocations: 5.128 GB, 38.60% gc time)
# WARNING: Method definition rhozw_f(Any) in module Main at In[216]:13 overwritten at In[219]:13.
# rhozw_f (generic function with 1 method)

# %%
# compute z entropies on the uniform (kde) grid
map(w->GynC.Hz(w, L_zuni_x, rhozw_f(w)), [w0, w])
# Out:
# 2-element Array{Float64,1}:
#  10.8603
#  10.8134

# %%
# optimize for z entropy with the uniform grid
gwdict["Hzuni"] = gradientascent(w->GynC.Hz(w, L_zuni_x, rhozw_f(w)), w0, 10, 0.01, GynC.projectsimplex)
# Out:
# 10-element Array{Any,1}:
#  [0.000576205,0.000778468,0.000976634,0.00117074,0.00136084,0.00154696,0.00172914,0.00190743,0.00208187,0.00225249  …  3.62458e-6,2.7847e-6,2.08429e-6,1.51124e-6,1.05329e-6,6.97982e-7,4.32675e-7,2.44547e-7,1.20592e-7,4.76203e-8]
#  [0.000288103,0.000530933,0.00134489,0.00188053,0.00213546,0.00217865,0.00208783,0.00194868,0.00185212,0.0018727  …  0.000429162,0.000495571,0.000562774,0.000630416,0.000698128,0.00076552,0.000832197,0.000897759,0.000961811,0.00102397]
