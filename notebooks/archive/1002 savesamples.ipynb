# %%
using JLD
s=[load("../data/0911/pl$(i)s0.1r1.1542383789674993t100atrue.jld", "sampling").samples for i=1:45]
# Out:
# WARNING: type GynC.Sampling not present in workspace; reconstructing
# WARNING: Method definition (::Type{JLD.##GynC.Sampling#1902})(Any, Any, Any) in module JLD at /home/numerik/bzfsikor/.julia/v0.5/JLD/src/jld_types.jl:760 overwritten at /home/numerik/bzfsikor/.julia/v0.5/JLD/src/jld_types.jl:760.
# WARNING: type GynC.Config not present in workspace; reconstructing
# WARNING: type GynC.Patient not present in workspace; reconstructing
# WARNING: Method definition (::Type{JLD.##GynC.Patient#1916})(Any, Any) in module JLD at /home/numerik/bzfsikor/.julia/v0.5/JLD/src/jld_types.jl:760 overwritten at /home/numerik/bzfsikor/.julia/v0.5/JLD/src/jld_types.jl:760.
# WARNING: type Distributions.Distribution{Distributions.Univariate,TypeVar(:S,Distributions.ValueSupport)} not present in workspace; interpreting array as Array{Any}
# WARNING: type Distributions.Truncated{Mamba.Flat,Distributions.Continuous} not present in workspace; reconstructing
# ...

# %%
save("../data/0911/allsamples.jld", "samples", s)
