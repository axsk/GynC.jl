# %%
addprocs(10)
using GynC
using Plots; gr()
# Out:
# WARNING: using Plots.density in module GynC conflicts with an existing identifier.
# WARNING: Method definition require(Symbol) in module Base at loading.jl:345 overwritten in module GynC at /home/numerik/bzfsikor/.julia/v0.5/Requires/src/require.jl:12.
# WARNING: using Plots.density in module GynC conflicts with an existing identifier.
# WARNING: using Plots.density in module GynC conflicts with an existing identifier.
# WARNING: using Plots.density in module GynC conflicts with an existing identifier.
# WARNING: using Plots.density in module GynC conflicts with an existing identifier.
# WARNING: using Plots.density in module GynC conflicts with an existing identifier.
# WARNING: using Plots.density in module GynC conflicts with an existing identifier.
# WARNING: using Plots.density in module GynC conflicts with an existing identifier.
# WARNING: using Plots.density in module GynC conflicts with an existing identifier.
# ...

# %%
rho_std = 3
rho_y = 0.6

nx = 200
ndata = 20
zmult = 500

srand(1)
m  = Federn.federmodel(nx, ndata, zmult, rho_std);
w0 = Federn.betaprior(m);

m.zsampledistr = Distributions.MvNormal(2, rho_y);
m.zs = Federn.perturb.(repmat(m.ys, zmult), rho_y);

# %%
reg = 1 - 1/ndata
#reg = 1
h=0.5
niter = 100
w = @time GynC.mple(m, w0, niter, 1, h)[end];
plot(m.xs, w)
# Out:
# INFO: computing likelihood matrix (100000x200)
#  29.386183 seconds (5.17 M allocations: 328.938 MB, 0.77% gc time)
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 52.3185,381.015 596.063,381.015 596.063,3.93701 52.3185,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="52" y="3" width="544" height="378"/>
#   </clipPath>
# </defs>
# ...

# %%
reg = 1 - 1/ndata
#reg = 1
h=0.5
niter = 100
w = @time GynC.mple(m, w0, niter, 1, h)[end];
plot(m.xs, w)
# Out:
# INFO: computing likelihood matrix (100000x200)
#  29.582315 seconds (5.19 M allocations: 329.514 MB, 0.72% gc time)
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 52.3185,381.015 596.063,381.015 596.063,3.93701 52.3185,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="52" y="3" width="544" height="378"/>
#   </clipPath>
# </defs>
# ...

# %%
plot(m.xs, GynC.mple(m, w0, niter, reg, h)[end])
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 52.3185,381.015 596.063,381.015 596.063,3.93701 52.3185,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="52" y="3" width="544" height="378"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   147.1,375.359 147.1,9.59318
#   "/>
# ...

# %%
include("../src/eb/plot.jl")
scatter(unfoldcols(m.ys))
# Out:
# WARNING: Method definition unfoldcols(Array{Array{#T<:Any, 1}, 1}) in module Main at /nfs/numerik/bzfsikor/dev/gc/src/eb/plot.jl:6 overwritten at /nfs/numerik/bzfsikor/dev/gc/src/eb/plot.jl:6.
# WARNING: Method definition plot_kde(Array{Array{#T<:Any, 1}, 1}, Array{T<:Any, 1}) in module Main at /nfs/numerik/bzfsikor/dev/gc/src/eb/plot.jl:12 overwritten at /nfs/numerik/bzfsikor/dev/gc/src/eb/plot.jl:12.
# WARNING: Method definition #plot_kde(Array{Any, 1}, Main.#plot_kde, Array{Array{#T<:Any, 1}, 1}, Array{T<:Any, 1}) in module Main overwritten.
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
# ...

# %%
cmax = 0.015
p1=plot_kde(m.ys, ones(length(m.ys))/length(m.ys), bandwidth = rho_y, xlim=(-20,20), ylim=(-20,20), clim=(0,cmax))
p2=plot_kde(m.ys, w, bandwidth = rho_y, xlim=(-20,20), ylim=(-20,20), clim=(0,cmax))
plot(p1,p2)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 34.5407,381.015 296.063,381.015 296.063,3.93701 34.5407,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="34" y="3" width="202" height="378"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   34.5407,375.359 34.5407,9.59318
#   "/>
# ...

# %%
scatter(unfoldcols(m.ys), ms=w*length(w)*5)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 34.5407,381.015 596.063,381.015 596.063,3.93701 34.5407,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="34" y="3" width="562" height="378"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   50.409,375.359 50.409,9.59318
#   "/>
# ...
