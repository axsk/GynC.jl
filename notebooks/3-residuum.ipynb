# %%
using GynC
using Colors
using Plots
# Out:
# WARNING: New definition
#     +(AbstractArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury) at /home/numerik/bzfsikor/.julia/v0.4/WoodburyMatrices/src/SymWoodburyMatrices.jl:106
# is ambiguous with:
#     +(DataArrays.DataArray, AbstractArray) at /home/numerik/bzfsikor/.julia/v0.4/DataArrays/src/operators.jl:276.
# To fix, define
#     +(DataArrays.DataArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury)
# before the new definition.
# WARNING: New definition
#     +(AbstractArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury) at /home/numerik/bzfsikor/.julia/v0.4/WoodburyMatrices/src/SymWoodburyMatrices.jl:106
# is ambiguous with:
#     +(DataArrays.AbstractDataArray, AbstractArray) at /home/numerik/bzfsikor/.julia/v0.4/DataArrays/src/operators.jl:300.
# To fix, define
#     +(DataArrays.AbstractDataArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury)
# before the new definition.
# WARNING: using Plots.density in module GynC conflicts with an existing identifier.

# %%
ss = GynC.readsamples("../data/0729")
# Out:
# 12-element Array{GynC.Sampling,1}:
#  Sampling
#   samples: (300000,116)
#   uniques: 49475
#   config:  Config:
#  patient: l1
#  sigma:   0.1
#  propvar trace: 0.00011599994199049544
#  adapt:   true
#  thin:    100
#  init:    4858380976513133059
#  prior:   Tuple{Array{Distributions.Distribution{Distributions.Univariate,S<:Distributions.ValueSupport},1},Distributions.MixtureModel{Distributions.Multivariate,Distributions.Continuous,Distributions.MvNormal{Float64,PDMats.PDiagMat{Float64,Array{Float64,1}},Array{Float64,1}}}}
#  Sampling
#   samples: (300000,116)
#   uniques: 41284
#   config:  Config:
#  patient: l1
#  sigma:   0.1
#  propvar trace: 0.011599420038662503
#  adapt:   true
#  thin:    100
#  init:    4858380976513133059
#  prior:   Tuple{Array{Distributions.Distribution{Distributions.Univariate,S<:Distributions.ValueSupport},1},Distributions.MixtureModel{Distributions.Multivariate,Distributions.Continuous,Distributions.MvNormal{Float64,PDMats.PDiagMat{Float64,Array{Float64,1}},Array{Float64,1}}}}
#  Sampling
#   samples: (300000,116)
#   uniques: 30085
#   config:  Config:
#  patient: l1
#  sigma:   0.1
#  propvar trace: 1.1542383789674993
#  adapt:   true
#  thin:    100
#  init:    4858380976513133059
#  prior:   Tuple{Array{Distributions.Distribution{Distributions.Univariate,S<:Distributions.ValueSupport},1},Distributions.MixtureModel{Distributions.Multivariate,Distributions.Continuous,Distributions.MvNormal{Float64,PDMats.PDiagMat{Float64,Array{Float64,1}},Array{Float64,1}}}}
#  Sampling
#   samples: (300000,116)
#   uniques: 54800
#   config:  Config:
#  patient: l1
#  sigma:   0.1
#  propvar trace: 1.1599999871501336e-6
#  adapt:   true
#  thin:    100
#  init:    4858380976513133059
#  prior:   Tuple{Array{Distributions.Distribution{Distributions.Univariate,S<:Distributions.ValueSupport},1},Distributions.MixtureModel{Distributions.Multivariate,Distributions.Continuous,Distributions.MvNormal{Float64,PDMats.PDiagMat{Float64,Array{Float64,1}},Array{Float64,1}}}}
#  Sampling
#   samples: (300000,116)
#   uniques: 44763
#   config:  Config:
#  patient: l2
#  sigma:   0.1
#  propvar trace: 0.00011599994199049544
#  adapt:   true
#  thin:    100
#  init:    4858380976513133059
#  prior:   Tuple{Array{Distributions.Distribution{Distributions.Univariate,S<:Distributions.ValueSupport},1},Distributions.MixtureModel{Distributions.Multivariate,Distributions.Continuous,Distributions.MvNormal{Float64,PDMats.PDiagMat{Float64,Array{Float64,1}},Array{Float64,1}}}}
#  Sampling
#   samples: (300000,116)
#   uniques: 57754
#   config:  Config:
#  patient: l2
#  sigma:   0.1
#  propvar trace: 0.011599420038662503
#  adapt:   true
#  thin:    100
#  init:    4858380976513133059
#  prior:   Tuple{Array{Distributions.Distribution{Distributions.Univariate,S<:Distributions.ValueSupport},1},Distributions.MixtureModel{Distributions.Multivariate,Distributions.Continuous,Distributions.MvNormal{Float64,PDMats.PDiagMat{Float64,Array{Float64,1}},Array{Float64,1}}}}
#  Sampling
#   samples: (300000,116)
#   uniques: 34886
#   config:  Config:
#  patient: l2
#  sigma:   0.1
#  propvar trace: 1.1542383789674993
#  adapt:   true
#  thin:    100
#  init:    4858380976513133059
#  prior:   Tuple{Array{Distributions.Distribution{Distributions.Univariate,S<:Distributions.ValueSupport},1},Distributions.MixtureModel{Distributions.Multivariate,Distributions.Continuous,Distributions.MvNormal{Float64,PDMats.PDiagMat{Float64,Array{Float64,1}},Array{Float64,1}}}}
#  Sampling
#   samples: (300000,116)
#   uniques: 65899
#   config:  Config:
#  patient: l2
#  sigma:   0.1
#  propvar trace: 1.1599999871501336e-6
#  adapt:   true
#  thin:    100
#  init:    4858380976513133059
#  prior:   Tuple{Array{Distributions.Distribution{Distributions.Univariate,S<:Distributions.ValueSupport},1},Distributions.MixtureModel{Distributions.Multivariate,Distributions.Continuous,Distributions.MvNormal{Float64,PDMats.PDiagMat{Float64,Array{Float64,1}},Array{Float64,1}}}}
#  Sampling
#   samples: (300000,116)
#   uniques: 50250
#   config:  Config:
#  patient: l3
#  sigma:   0.1
#  propvar trace: 0.00011599994199049544
#  adapt:   true
#  thin:    100
#  init:    4858380976513133059
#  prior:   Tuple{Array{Distributions.Distribution{Distributions.Univariate,S<:Distributions.ValueSupport},1},Distributions.MixtureModel{Distributions.Multivariate,Distributions.Continuous,Distributions.MvNormal{Float64,PDMats.PDiagMat{Float64,Array{Float64,1}},Array{Float64,1}}}}
#  Sampling
#   samples: (300000,116)
#   uniques: 32656
#   config:  Config:
#  patient: l3
#  sigma:   0.1
#  propvar trace: 0.011599420038662503
#  adapt:   true
#  thin:    100
#  init:    4858380976513133059
#  prior:   Tuple{Array{Distributions.Distribution{Distributions.Univariate,S<:Distributions.ValueSupport},1},Distributions.MixtureModel{Distributions.Multivariate,Distributions.Continuous,Distributions.MvNormal{Float64,PDMats.PDiagMat{Float64,Array{Float64,1}},Array{Float64,1}}}}
#  Sampling
#   samples: (300000,116)
#   uniques: 26344
#   config:  Config:
#  patient: l3
#  sigma:   0.1
#  propvar trace: 1.1542383789674993
#  adapt:   true
#  thin:    100
#  init:    4858380976513133059
#  prior:   Tuple{Array{Distributions.Distribution{Distributions.Univariate,S<:Distributions.ValueSupport},1},Distributions.MixtureModel{Distributions.Multivariate,Distributions.Continuous,Distributions.MvNormal{Float64,PDMats.PDiagMat{Float64,Array{Float64,1}},Array{Float64,1}}}}
#  Sampling
#   samples: (300000,116)
#   uniques: 76993
#   config:  Config:
#  patient: l3
#  sigma:   0.1
#  propvar trace: 1.1599999871501336e-6
#  adapt:   true
#  thin:    100
#  init:    4858380976513133059
#  prior:   Tuple{Array{Distributions.Distribution{Distributions.Univariate,S<:Distributions.ValueSupport},1},Distributions.MixtureModel{Distributions.Multivariate,Distributions.Continuous,Distributions.MvNormal{Float64,PDMats.PDiagMat{Float64,Array{Float64,1}},Array{Float64,1}}}}

# %%
gr()
plotsolutions(ss[1][100_000:3000:end,:], seriesalpha = 1, x=0:120)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 35.4331,177.078 296.063,177.078 296.063,3.93701 35.4331,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="35" y="3" width="261" height="174"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   35.4331,174.481 35.4331,6.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   78.8714,174.481 78.8714,6.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   122.31,174.481 122.31,6.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   165.748,174.481 165.748,6.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   209.186,174.481 209.186,6.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   252.625,174.481 252.625,6.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   296.063,174.481 296.063,6.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.3425,142.166 292.154,142.166
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.3425,107.088 292.154,107.088
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.3425,72.0107 292.154,72.0107
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.3425,36.9331 292.154,36.9331
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,177.078 296.063,177.078
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,3.93701 296.063,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,177.078 35.4331,174.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,3.93701 35.4331,6.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   78.8714,177.078 78.8714,174.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   78.8714,3.93701 78.8714,6.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   122.31,177.078 122.31,174.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   122.31,3.93701 122.31,6.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   165.748,177.078 165.748,174.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   165.748,3.93701 165.748,6.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   209.186,177.078 209.186,174.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   209.186,3.93701 209.186,6.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   252.625,177.078 252.625,174.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   252.625,3.93701 252.625,6.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   296.063,177.078 296.063,174.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   296.063,3.93701 296.063,6.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,177.078 35.4331,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   296.063,177.078 296.063,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,142.166 39.3425,142.166
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   296.063,142.166 292.154,142.166
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,107.088 39.3425,107.088
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   296.063,107.088 292.154,107.088
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,72.0107 39.3425,72.0107
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   296.063,72.0107 292.154,72.0107
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,36.9331 39.3425,36.9331
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   296.063,36.9331 292.154,36.9331
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 35.4331, 193.878)" x="35.4331" y="193.878">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 78.8714, 193.878)" x="78.8714" y="193.878">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 122.31, 193.878)" x="122.31" y="193.878">40</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 165.748, 193.878)" x="165.748" y="193.878">60</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 209.186, 193.878)" x="209.186" y="193.878">80</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#0

# %%
plotn = 1000
prior = JLD.load("merged.jld", "w")

xrange  = 0:1/10:30

meascol = colorant"tomato"
refcol = colorant"black"

postcol = colorant"mediumaquamarine"
ppostcol = colorant"steelblue"

plotsize=(800, 500)

factors=[1,1,3.6712,1]

map([8, 23]) do patient
  s = load("../data/batch/pl$(patient)s0.1r0.125t100atrue.jld")
  n = size(s.samples, 1)
  samplerange = 20_000:div(n,plotn):n;
    
  plots = []
  
  post=deepcopy(prior)
  post.likelihoods = reshape(post.likelihoods[:,patient], size(post.likelihoods,1), 1)
  emiteration!(post)

  samples = GynC.sample(post, plotn)
  samplesols = [GynC.gync(samples[i,:]|>vec, xrange)[:, GynC.measuredinds] for i in 1:plotn]

  for spec = 1:4
    p = Plots.plot()#size=plotsize)
    plotdata(s, spec, p=p, ms=6, label="patient data", color=meascol)
    plot!(xrange, GynC.referencesolution(step(xrange))[:,GynC.measuredinds[spec]] * factors[spec], label="reference", legend=true, color=refcol)

    #plotsolutions(s[samplerange, :], spec, x=xrange, p=p, color=postcol, width=0.1, alpha=0.2, label="")
    #plot!([NaN],label="posterior sample",color=postcol) 

    #traj = hcat(Vector{Float64}[GynC.gync(samples[i,:]|>vec, xrange)[:, GynC.measuredinds[spec]]|>vec for i in 1:size(samples,1)]...);
    traj = [sol[:, spec]|>vec for sol in samplesols]
    plot!(xrange, traj, color=ppostcol, width=0.1, alpha=0.1, label="")
    plot!([NaN],label="posterior samples",color=ppostcol)
    push!(plots, p)
  end
  p = plot(plots..., layout=4, size=plotsize) 
  display(p)
end
# Out:
# <img src="data:image/png;base64,..." />
# <img src="data:image/png;base64,..." />
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f9952fc1690>)
# 2-element Array{Void,1}:
#  nothing
#  nothing

# %%
#=let s = s[plotrange,:]# jumpsize plot
  p = plot()
  for i = [1,8,50,90,110]
      u=unique(s.samples[:,i]) 
      x = map(x->findfirst(s.samples[:,i], x), u)
      v = (u[2:end] - u[1:end-1]) ./ s.samples[1,i]
      scatter!(x, v, label=i, m=(3,stroke(0)))
  end
  p
end
=#

# %%
plot(plotrange, (s.samples[plotrange, :] #=./ s.samples[1,:]=#)[:,82+[2,7,24,25]])
# Out:
# <img src="data:image/png;base64,..." />

# %%
plot(plotrange, [GynC.llh(s.config, s.samples[i,:]|>vec) for i in plotrange], title="loglikelihood")
# Out:
# <img src="data:image/png;base64,..." />
