# %%
using GynC: readsamples, dataframe, data, hzobj
ss=readsamples("../data/0911")
# Out:
# LoadError: TypeError: deserialize: in typeassert, expected Module, got Type{Any}
# while loading In[8], in expression starting on line 2
#
#  in deserialize(::SerializationState{Base.AbstractIOBuffer{Array{UInt8,1}}}, ::Type{Module}) at ./serialize.jl:602
#  in handle_deserialize(::SerializationState{Base.AbstractIOBuffer{Array{UInt8,1}}}, ::Int32) at ./serialize.jl:581
#  in deserialize(::SerializationState{Base.AbstractIOBuffer{Array{UInt8,1}}}) at ./serialize.jl:541
#  in deserialize_datatype(::SerializationState{Base.AbstractIOBuffer{Array{UInt8,1}}}) at ./serialize.jl:822
#  in handle_deserialize(::SerializationState{Base.AbstractIOBuffer{Array{UInt8,1}}}, ::Int32) at ./serialize.jl:571
#  in deserialize(::SerializationState{Base.AbstractIOBuffer{Array{UInt8,1}}}) at ./serialize.jl:541
#  in deserialize(::Base.AbstractIOBuffer{Array{UInt8,1}}) at ./serialize.jl:538
#  in readas(::GynC.Serializer) at /home/numerik/bzfsikor/.julia/v0.5/GynC/src/utils.jl:39
#  in read_scalar(::JLD.JldDataset, ::HDF5.HDF5Datatype, ::Type{T}) at /home/numerik/bzfsikor/.julia/v0.5/JLD/src/JLD.jl:418
#  in read(::JLD.JldDataset) at /home/numerik/bzfsikor/.julia/v0.5/JLD/src/JLD.jl:390
#  in read_ref(::JLD.JldFile, ::HDF5.HDF5ReferenceObj) at /home/numerik/bzfsikor/.julia/v0.5/JLD/src/JLD.jl:518
#  in jlconvert(::Type{GynC.Sampling}, ::JLD.JldFile, ::Ptr{UInt8}) at /home/numerik/bzfsikor/.julia/v0.5/JLD/src/jld_types.jl:432
#  in read_scalar(::JLD.JldDataset, ::HDF5.HDF5Datatype, ::Type{T}) at /home/numerik/bzfsikor/.julia/v0.5/JLD/src/JLD.jl:418
#  in read(::JLD.JldDataset) at /home/numerik/bzfsikor/.julia/v0.5/JLD/src/JLD.jl:390
#  in read(::JLD.JldFile, ::String) at /home/numerik/bzfsikor/.julia/v0.5/JLD/src/JLD.jl:366
#  in #jldopen#9(::Array{Any,1}, ::Function, ::JLD.##39#40{String}, ::String, ::Vararg{String,N}) at /home/numerik/bzfsikor/.julia/v0.5/JLD/src/JLD.jl:265
#  in load(::FileIO.File{FileIO.DataFormat{:JLD}}, ::String) at /home/numerik/bzfsikor/.julia/v0.5/JLD/src/JLD.jl:1226
#  in #load#13(::Array{Any,1}, ::Function, ::String, ::String, ::Vararg{String,N}) at /home/numerik/bzfsikor/.julia/v0.5/FileIO/src/loadsave.jl:45
#  in _collect(::Array{String,1}, ::Base.Generator{Array{String,1},GynC.##31#34}, ::Base.EltypeUnknown, ::Base.HasShape) at ./array.jl:320
#  in (::GynC.##29#32)() at /home/numerik/bzfsikor/.julia/v0.5/GynC/src/utils.jl:58
#  in cd(::GynC.##29#32, ::String) at ./file.jl:59
#  in readsamples(::String) at /home/numerik/bzfsikor/.julia/v0.5/GynC/src/utils.jl:56

# %%
?GynC.dataframe
# Out:
# No documentation found.
#
# `GynC.dataframe` is a `Function`.
#
# ```
# # 1 method for generic function "dataframe":
# dataframe(ss::Array{GynC.Sampling,1}) at /home/numerik/bzfsikor/.julia/v0.5/GynC/src/utils.jl:63
# ```

# %%
ss
# Out:
# LoadError: UndefVarError: ss not defined
# while loading In[5], in expression starting on line 1

# %%
datas = [data(s) for s in ss];
x=vcat([s.samples[1:1000:20000,:] for s in ss]...)
# Out:
# 900x116 Array{Float64,2}:
#   7309.9    7309.9   192.2     2.371    …  3.3169e-5   2.9879e-5   28.0
#   8878.67   6354.57  226.312   2.12303     3.89578e-5  1.80161e-5  27.6444
#   8219.94   6018.49  216.786   1.4548      3.5427e-5   2.57119e-5  28.5116
#  13686.1    6790.4   324.427   2.80569     4.39839e-5  2.14427e-5  27.3692
#  16824.6    7741.02  459.296   2.82709     3.49722e-5  2.48237e-5  26.9132
#  13061.5    6887.27  326.628   4.14603  …  2.58883e-5  1.85626e-5  28.684
#  10847.2    6249.34  375.124   2.51081     3.45316e-5  1.98175e-5  28.7088
#  13139.2    9107.13  324.435   4.16463     3.39051e-5  2.89039e-5  28.5406
#  10280.7   10440.7   301.69    3.13941     4.61279e-5  2.88888e-5  29.8739
#  15636.6   14270.3   325.84    5.60388     4.92687e-5  2.86894e-5  28.1297
#  16834.9   16910.5   464.457   3.29516  …  4.56624e-5  1.99933e-5  27.1589
#   9119.81  14516.1   601.791   3.25238     4.79829e-5  1.39903e-5  28.8607
#  10519.9   10695.1   341.461   4.10406     2.6239e-5   2.52047e-5  28.5704
#      ⋮                                  ⋱                           ⋮
#  10773.7    6554.29   82.3842  2.11814     6.4612e-5   6.82504e-5  31.3173
#   9384.67   5286.41   65.1009  2.42897     5.93892e-5  9.90261e-5  28.6821
#   8865.27   7233.01   83.9565  2.12291  …  6.73286e-5  7.54507e-5  30.4787
#  11065.8    7810.93   67.7993  2.23662     6.6016e-5   8.23328e-5  29.056
#  10372.2    4884.72   77.6902  2.62877     5.54461e-5  8.18918e-5  30.6021
#   9151.07   5087.0    84.7996  1.92651     6.91584e-5  7.54051e-5  29.2165
#   9302.07   8697.11  124.025   3.59959     6.19089e-5  8.88608e-5  30.6265
#   7653.61   6074.89   64.9691  4.15876  …  3.6095e-5   9.64886e-5  29.1132
#  10230.7    6651.52   81.0906  3.70215     5.19371e-5  8.91659e-5  29.8692
#  13193.6    6305.79   86.2988  2.50995     5.3081e-5   9.69974e-5  28.8359
#  10029.7    7884.4    92.1782  2.10457     5.66614e-5  6.35493e-5  30.7876
#  18391.5    8410.76  184.685   1.98386     6.54924e-5  5.05028e-5  31.4924

# %%
@show K = size(x, 1)
@show M = length(datas)
@time o = hzobj(x,datas)

using BenchmarkTools
@benchmark o(rand(K))
# Out:
# K = size(x,1) = 900
# M = length(datas) = 45
# [CVODES WARNING]  CVode
#   Internal t = 26.6578 and h = 1.72979e-15 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.6578 and h = 1.04051e-15 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.6578 and h = 1.04051e-15 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.6578 and h = 3.9913e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.6578 and h = 3.05689e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.6578 and h = 3.05689e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.6578 and h = 3.05689e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.6578 and h = 4.71587e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.6578 and h = 1.95871e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.6578 and h = 1.95871e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   The above warning has been issued mxhnil times and will not be issued again for this problem.
#
#
# [CVODES ERROR]  CVode
#   At t = 26.6578, mxstep steps taken before reaching tout.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 25.7687 and h = 1.28588e-15 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 25.7687 and h = 6.87213e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 25.7687 and h = 4.09003e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 25.7687 and h = 2.06944e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 25.7687 and h = 1.26951e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 25.7687 and h = 8.60729e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 25.7687 and h = 2.15182e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 25.7687 and h = 2.15182e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 25.7687 and h = 2.15182e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 25.7687 and h = 3.58761e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   The above warning has been issued mxhnil times and will not be issued again for this problem.
#
#
# [CVODES ERROR]  CVode
#   At t = 25.7687, mxstep steps taken before reaching tout.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 29.1952 and h = 1.6013e-15 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 29.1952 and h = 1.6013e-15 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 29.1952 and h = 1.41879e-15 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 29.1952 and h = 1.38371e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 29.1952 and h = 1.38371e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 29.1952 and h = 3.32962e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 29.1952 and h = 1.59961e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 29.1952 and h = 1.82842e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 29.1952 and h = 1.82842e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 29.1952 and h = 1.64616e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   The above warning has been issued mxhnil times and will not be issued again for this problem.
#
#
# [CVODES ERROR]  CVode
#   At t = 29.1952, mxstep steps taken before reaching tout.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.5655 and h = 8.73815e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.5655 and h = 4.44009e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.5655 and h = 1.11002e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.5655 and h = 1.11002e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.5655 and h = 2.0351e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.5655 and h = 2.8382e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.5655 and h = 2.8382e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.5655 and h = 2.5758e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.5655 and h = 2.5758e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.5655 and h = 2.42271e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   The above warning has been issued mxhnil times and will not be issued again for this problem.
#
#
# [CVODES ERROR]  CVode
#   At t = 27.5656, mxstep steps taken before reaching tout.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.9867 and h = 1.22217e-15 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.9867 and h = 1.22217e-15 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.9867 and h = 3.05543e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.9867 and h = 3.05543e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.9867 and h = 3.05543e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.9867 and h = 1.37834e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.9867 and h = 3.44586e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.9867 and h = 8.61465e-18 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.9867 and h = 8.61465e-18 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.9867 and h = 2.42332e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   The above warning has been issued mxhnil times and will not be issued again for this problem.
#
#
# [CVODES ERROR]  CVode
#   At t = 27.9867, mxstep steps taken before reaching tout.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.3479 and h = 1.32245e-15 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.3479 and h = 7.70592e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.3479 and h = 4.62587e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.3479 and h = 2.67836e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.3479 and h = 1.66176e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.3479 and h = 8.57052e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.3479 and h = 8.57052e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.3479 and h = 3.51552e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.3479 and h = 1.48914e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.3479 and h = 3.72286e-18 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   The above warning has been issued mxhnil times and will not be issued again for this problem.
#
#
# [CVODES ERROR]  CVode
#   At t = 26.3479, mxstep steps taken before reaching tout.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 5.80966 and h = 4.2534e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 5.80966 and h = 4.2534e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 5.80966 and h = 4.2534e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 5.80966 and h = 4.2534e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 5.80966 and h = 4.2534e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 5.80966 and h = 2.52788e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 5.80966 and h = 2.52788e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 5.80966 and h = 2.52788e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 5.80966 and h = 2.52788e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 5.80966 and h = 2.52788e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   The above warning has been issued mxhnil times and will not be issued again for this problem.
#
#
# [CVODES ERROR]  CVode
#   At t = 5.80966, mxstep steps taken before reaching tout.
#  32.037364 seconds (216.93 M allocations: 11.220 GB, 16.30% gc time)
# BenchmarkTools.Trial:
#   samples:          1469
#   evals/sample:     1
#   time tolerance:   5.00%
#   memory tolerance: 1.00%
#   memory estimate:  28.97 kb
#   allocs estimate:  11
#   minimum time:     3.34 ms (0.00% GC)
#   median time:      3.37 ms (0.00% GC)
#   mean time:        3.39 ms (0.18% GC)
#   maximum time:     12.52 ms (69.93% GC)

# %%
Profile.clear()
@profile o = hzobj(x,datas)
Profile.print()
# Out:
# [CVODES WARNING]  CVode
#   Internal t = 26.6578 and h = 1.72979e-15 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.6578 and h = 1.04051e-15 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.6578 and h = 1.04051e-15 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.6578 and h = 3.9913e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.6578 and h = 3.05689e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.6578 and h = 3.05689e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.6578 and h = 3.05689e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.6578 and h = 4.71587e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.6578 and h = 1.95871e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.6578 and h = 1.95871e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   The above warning has been issued mxhnil times and will not be issued again for this problem.
#
#
# [CVODES ERROR]  CVode
#   At t = 26.6578, mxstep steps taken before reaching tout.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 25.7687 and h = 1.28588e-15 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 25.7687 and h = 6.87213e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 25.7687 and h = 4.09003e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 25.7687 and h = 2.06944e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 25.7687 and h = 1.26951e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 25.7687 and h = 8.60729e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 25.7687 and h = 2.15182e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 25.7687 and h = 2.15182e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 25.7687 and h = 2.15182e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 25.7687 and h = 3.58761e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   The above warning has been issued mxhnil times and will not be issued again for this problem.
#
#
# [CVODES ERROR]  CVode
#   At t = 25.7687, mxstep steps taken before reaching tout.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 29.1952 and h = 1.6013e-15 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 29.1952 and h = 1.6013e-15 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 29.1952 and h = 1.41879e-15 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 29.1952 and h = 1.38371e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 29.1952 and h = 1.38371e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 29.1952 and h = 3.32962e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 29.1952 and h = 1.59961e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 29.1952 and h = 1.82842e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 29.1952 and h = 1.82842e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 29.1952 and h = 1.64616e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   The above warning has been issued mxhnil times and will not be issued again for this problem.
#
#
# [CVODES ERROR]  CVode
#   At t = 29.1952, mxstep steps taken before reaching tout.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.5655 and h = 8.73815e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.5655 and h = 4.44009e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.5655 and h = 1.11002e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.5655 and h = 1.11002e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.5655 and h = 2.0351e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.5655 and h = 2.8382e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.5655 and h = 2.8382e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.5655 and h = 2.5758e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.5655 and h = 2.5758e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.5655 and h = 2.42271e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   The above warning has been issued mxhnil times and will not be issued again for this problem.
#
#
# [CVODES ERROR]  CVode
#   At t = 27.5656, mxstep steps taken before reaching tout.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.9867 and h = 1.22217e-15 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.9867 and h = 1.22217e-15 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.9867 and h = 3.05543e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.9867 and h = 3.05543e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.9867 and h = 3.05543e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.9867 and h = 1.37834e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.9867 and h = 3.44586e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.9867 and h = 8.61465e-18 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.9867 and h = 8.61465e-18 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 27.9867 and h = 2.42332e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   The above warning has been issued mxhnil times and will not be issued again for this problem.
#
#
# [CVODES ERROR]  CVode
#   At t = 27.9867, mxstep steps taken before reaching tout.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.3479 and h = 1.32245e-15 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.3479 and h = 7.70592e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.3479 and h = 4.62587e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.3479 and h = 2.67836e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.3479 and h = 1.66176e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.3479 and h = 8.57052e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.3479 and h = 8.57052e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.3479 and h = 3.51552e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.3479 and h = 1.48914e-17 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 26.3479 and h = 3.72286e-18 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   The above warning has been issued mxhnil times and will not be issued again for this problem.
#
#
# [CVODES ERROR]  CVode
#   At t = 26.3479, mxstep steps taken before reaching tout.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 5.80966 and h = 4.2534e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 5.80966 and h = 4.2534e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 5.80966 and h = 4.2534e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 5.80966 and h = 4.2534e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 5.80966 and h = 4.2534e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 5.80966 and h = 2.52788e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 5.80966 and h = 2.52788e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 5.80966 and h = 2.52788e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 5.80966 and h = 2.52788e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 5.80966 and h = 2.52788e-16 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   The above warning has been issued mxhnil times and will not be issued again for this problem.
#
#
# [CVODES ERROR]  CVode
#   At t = 5.80966, mxstep steps taken before reaching tout.
# 1875  ...undials/src/simple.jl; cvodefun; line: 78
#  1529 .../GynC/src/gyncycle.jl; anonymous; line: 8
#   3   .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 42
#   77  .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 81
#   3   .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 82
#   73  .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 85
#   61  .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 86
#   1   .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 87
#   4   .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 90
#   1   .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 93
#   1   .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 96
#   1   .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 99
#   219 .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 102
#   54  .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 103
#   1   .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 110
#   2   .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 116
#   123 .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 119
#   94  .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 122
#   96  .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 126
#   1   .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 129
#   76  .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 132
#   59  .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 137
#   62  .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 142
#   133 .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 146
#   68  .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 149
#   1   .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 152
#   64  .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 155
#   47  .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 158
#   76  .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 161
#   76  .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 164
#   5   .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 167
#   1   .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 190
#   3   .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 196
#   1   .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 199
#   4   .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 205
#   1   .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 212
#   1   .../GynC/src/gyncycle.jl; gyncycle_rhs!; line: 218
#  3    ...rc/nvector_wrapper.jl; release_handle; line: 28
#   2 ...undials/src/nvector.jl; __N_VDestroy_Serial; line: 86
#   1 ...src/nvector_wrapper.jl; call; line: 24
# 7     ...undials/src/simple.jl; cvodefun; line: 79
# 31824 task.jl; anonymous; line: 447
#  31824 ...ulia/src/eventloop.jl; eventloop; line: 8
#   31824 ...c/execute_request.jl; execute_request; line: 169
#    31824 loading.jl; include_string; line: 282
#     31824 profile.jl; anonymous; line: 16
#      4553  .../GynC/src/optim2.jl; hzobj; line: 12
#       4553 .../GynC/src/optim2.jl; phi; line: 34
#        4542 .../GynC/src/optim2.jl; phi; line: 33
#         4541 .../GynC/src/model.jl; forwardsol; line: 87
#          4537 ...nC/src/gyncycle.jl; gync; line: 8
#           4532 ...als/src/simple.jl; cvode; line: 102
#            4511 ...als/src/simple.jl; cvode; line: 15
#             4497 ...als/src/cvodes.jl; __CVode; line: 416
#              1177 ...als/src/simple.jl; cvodefun; line: 78
#               1177 ...C/src/gyncycle.jl; anonymous; line: 8
#                68  .../src/gyncycle.jl; gyncycle_rhs!; line: 81
#                4   .../src/gyncycle.jl; gyncycle_rhs!; line: 82
#                45  .../src/gyncycle.jl; gyncycle_rhs!; line: 85
#                40  .../src/gyncycle.jl; gyncycle_rhs!; line: 86
#                1   .../src/gyncycle.jl; gyncycle_rhs!; line: 87
#                2   .../src/gyncycle.jl; gyncycle_rhs!; line: 90
#                1   .../src/gyncycle.jl; gyncycle_rhs!; line: 96
#                1   .../src/gyncycle.jl; gyncycle_rhs!; line: 99
#                166 .../src/gyncycle.jl; gyncycle_rhs!; line: 102
#                53  .../src/gyncycle.jl; gyncycle_rhs!; line: 103
#                2   .../src/gyncycle.jl; gyncycle_rhs!; line: 104
#                1   .../src/gyncycle.jl; gyncycle_rhs!; line: 107
#                1   .../src/gyncycle.jl; gyncycle_rhs!; line: 110
#                92  .../src/gyncycle.jl; gyncycle_rhs!; line: 119
#                65  .../src/gyncycle.jl; gyncycle_rhs!; line: 122
#                84  .../src/gyncycle.jl; gyncycle_rhs!; line: 126
#                1   .../src/gyncycle.jl; gyncycle_rhs!; line: 129
#                57  .../src/gyncycle.jl; gyncycle_rhs!; line: 132
#                50  .../src/gyncycle.jl; gyncycle_rhs!; line: 137
#                46  .../src/gyncycle.jl; gyncycle_rhs!; line: 142
#                79  .../src/gyncycle.jl; gyncycle_rhs!; line: 146
#                43  .../src/gyncycle.jl; gyncycle_rhs!; line: 149
#                67  .../src/gyncycle.jl; gyncycle_rhs!; line: 155
#                51  .../src/gyncycle.jl; gyncycle_rhs!; line: 158
#                55  .../src/gyncycle.jl; gyncycle_rhs!; line: 161
#                42  .../src/gyncycle.jl; gyncycle_rhs!; line: 164
#                1   .../src/gyncycle.jl; gyncycle_rhs!; line: 167
#                5   .../src/gyncycle.jl; gyncycle_rhs!; line: 180
#                2   .../src/gyncycle.jl; gyncycle_rhs!; line: 190
#                1   .../src/gyncycle.jl; gyncycle_rhs!; line: 193
#                2   .../src/gyncycle.jl; gyncycle_rhs!; line: 196
#                4   .../src/gyncycle.jl; gyncycle_rhs!; line: 199
#                3   .../src/gyncycle.jl; gyncycle_rhs!; line: 205
#                3   .../src/gyncycle.jl; gyncycle_rhs!; line: 212
#             5    ...als/src/cvodes.jl; __CVodeInit; line: 14
#            3    ...als/src/simple.jl; cvode; line: 103
#            2    ...als/src/simple.jl; cvode; line: 111
#             1 array.jl; fill!; line: 193
#             1 essentials.jl; call; line: 201
#            1    ...als/src/simple.jl; cvode; line: 112
#            8    ...als/src/simple.jl; cvode; line: 124
#             2 cartesian.jl; _unsafe_batchsetindex!; line: 37
#             1 multidimensional.jl; _unsafe_batchsetindex!; line: 320
#             2 multidimensional.jl; _unsafe_batchsetindex!; line: 328
#             1 multidimensional.jl; _unsafe_batchsetindex!; line: 329
#            2    ...als/src/simple.jl; cvode; line: 127
#             2 ...ials/src/cvodes.jl; CVodeFree; line: 188
#            2    tuple.jl; indexed_next; line: 21
#          4    array.jl; getindex; line: 289
#           1 array.jl; unsafe_getindex; line: 292
#           3 array.jl; unsafe_getindex; line: 294
#            3 array.jl; unsafe_copy!; line: 80
#         1    multidimensional.jl; _unsafe_getindex; line: 193
#        3    multidimensional.jl; _unsafe_getindex; line: 195
#      8     .../GynC/src/optim2.jl; hzobj; line: 13
#       8 ....4/GynC/src/optim2.jl; addmeaserror; line: 24
#        8 abstractarray.jl; map; line: 1308
#         8 abstractarray.jl; map_to!; line: 1286
#          8 .../GynC/src/optim2.jl; anonymous; line: 24
#           5 ...rc/multivariates.jl; rand; line: 18
#            2 broadcast.jl; broadcast!; line: 246
#             2 broadcast.jl; _F_; line: 89
#              1 broadcast.jl; check_broadcast_shape; line: 52
#              1 broadcast.jl; check_broadcast_shape; line: 55
#            3 random.jl; randn!; line: 1135
#           2 arraymath.jl; +; line: 96
#      1045  .../GynC/src/optim2.jl; hzobj; line: 15
#       1045 .../GynC/src/optim2.jl; L; line: 27
#        2   .../GynC/src/optim2.jl; rho_e_m; line: 39
#        496 .../GynC/src/optim2.jl; rho_e_m; line: 41
#         146 abstractarraymath.jl; vec; line: 14
#          4   array.jl; reshape; line: 145
#          142 array.jl; reshape; line: 148
#         4   multidimensional.jl; _unsafe_getindex; line: 192
#         302 multidimensional.jl; _unsafe_getindex; line: 193
#          3 abstractarray.jl; trailingsize; line: 98
#          2 abstractarray.jl; trailingsize; line: 99
#         15  multidimensional.jl; _unsafe_getindex; line: 194
#          8 multidimensional.jl; checksize; line: 270
#          1 multidimensional.jl; checksize; line: 272
#         23  multidimensional.jl; _unsafe_getindex; line: 195
#        226 .../GynC/src/optim2.jl; rho_e_m; line: 42
#         155 operators.jl; isnan; line: 380
#         11  reduce.jl; any; line: 358
#          2 reduce.jl; mapreduce_sc_impl; line: 187
#          3 reduce.jl; mapreduce_sc_impl; line: 188
#         1   reduce.jl; mapreduce_sc_impl; line: 187
#        262 .../GynC/src/optim2.jl; rho_e_m; line: 43
#         1   ...rc/multivariates.jl; logpdf; line: 63
#         202 ...rc/multivariates.jl; logpdf; line: 65
#          1   ...DMats/src/utils.jl; wsumsq; line: 56
#          3   ...DMats/src/utils.jl; wsumsq; line: 57
#          181 operators.jl; log; line: 380
#          1   reduce.jl; _mapreduce; line: 137
#          2   reduce.jl; _mapreduce; line: 140
#          2   reduce.jl; _mapreduce; line: 153
#        1   .../GynC/src/optim2.jl; rho_e_m; line: 45
#        43  arraymath.jl; -; line: 96
#        1   essentials.jl; convert; line: 59
#      26218 .../GynC/src/optim2.jl; hzobj; line: 16
#       26218 .../GynC/src/optim2.jl; L; line: 27
#        17    ...GynC/src/optim2.jl; rho_e_m; line: 39
#        12    ...GynC/src/optim2.jl; rho_e_m; line: 40
#        10353 ...GynC/src/optim2.jl; rho_e_m; line: 41
#         12   abstractarray.jl; trailingsize; line: 98
#         1    abstractarray.jl; trailingsize; line: 101
#         4084 abstractarraymath.jl; vec; line: 14
#          107  array.jl; reshape; line: 145
#          3941 array.jl; reshape; line: 148
#         7    array.jl; reshape; line: 145
#         11   array.jl; reshape; line: 148
#         21   multidimensional.jl; _unsafe_getindex; line: 189
#         53   multidimensional.jl; _unsafe_getindex; line: 192
#         5179 multidimensional.jl; _unsafe_getindex; line: 193
#          33 abstractarray.jl; trailingsize; line: 98
#          43 abstractarray.jl; trailingsize; line: 99
#         268  multidimensional.jl; _unsafe_getindex; line: 194
#          165 multidimensional.jl; checksize; line: 270
#          24  multidimensional.jl; checksize; line: 272
#         437  multidimensional.jl; _unsafe_getindex; line: 195
#         9    multidimensional.jl; checksize; line: 270
#         13   multidimensional.jl; checksize; line: 272
#        4695  ...GynC/src/optim2.jl; rho_e_m; line: 42
#         3003 operators.jl; isnan; line: 380
#         249  reduce.jl; any; line: 358
#          39 reduce.jl; mapreduce_sc_impl; line: 187
#          58 reduce.jl; mapreduce_sc_impl; line: 188
#         10   reduce.jl; mapreduce_sc_impl; line: 187
#        9487  ...GynC/src/optim2.jl; rho_e_m; line: 43
#         10   ./float.jl; +; line: 0
#         27   ./float.jl; +; line: 208
#         76   ...c/multivariates.jl; logpdf; line: 63
#         6661 ...c/multivariates.jl; logpdf; line: 65
#          30   ...DMats/src/utils.jl; wsumsq; line: 6
#          23   ...DMats/src/utils.jl; wsumsq; line: 56
#          173  ...DMats/src/utils.jl; wsumsq; line: 57
#          6060 operators.jl; log; line: 380
#          14   reduce.jl; _mapreduce; line: 137
#          3    reduce.jl; _mapreduce; line: 139
#          6    reduce.jl; _mapreduce; line: 140
#          4    reduce.jl; _mapreduce; line: 142
#          17   reduce.jl; _mapreduce; line: 143
#          11   reduce.jl; _mapreduce; line: 145
#          12   reduce.jl; _mapreduce; line: 147
#          13   reduce.jl; _mapreduce; line: 148
#          39   reduce.jl; _mapreduce; line: 149
#          9    reduce.jl; _mapreduce; line: 153
#         6    ...DMats/src/utils.jl; wsumsq; line: 6
#         7    ...DMats/src/utils.jl; wsumsq; line: 59
#         11   operators.jl; log; line: 380
#         15   reduce.jl; _mapreduce; line: 137
#        127   ...GynC/src/optim2.jl; rho_e_m; line: 45
#         68 math.jl; exp; line: 113
#        4     abstractarraymath.jl; vec; line: 14
#        1096  arraymath.jl; -; line: 96
#         2 operators.jl; promote_shape; line: 219
#        1     arraymath.jl; -; line: 97
#        5     arraymath.jl; -; line: 100
#        2     essentials.jl; convert; line: 59
#        1     multidimensional.jl; _unsafe_getindex; line: 195

# %% [markdown]
# K|M|precalc (s)|eval (ms)
# ---|---|---|---
# 90|45|1.75|0.05
# 900|45|32|3.69

# %% [markdown]
# ## Optimization

# %%
# given a function f: R^dim -> R, return a function 
# g(x,g) which returns f(x) and stores f'(x) in g
# the format u
function gradify(f, dim)
    grad = ForwardDiff.GradientResult(rand(dim))
    function gradifiedf(w,g)
        ForwardDiff.gradient!(grad, f, w)
        if length(g) > 0
            g[:] = ForwardDiff.gradient(grad)
        end
        ForwardDiff.value(grad)
    end
end

obj2 = gradify(w->o(w/sum(w)), K)

using NLopt

ln = [:GN_ISRES, :LN_COBYLA, :LN_BOBYQA, :LN_NEWUOA_BOUND, :LN_PRAXIS, :LN_NELDERMEAD, :LN_SBPLX]
ld = [:LD_LBFGS, :LD_MMA, :LD_SLSQP]
opt = Opt(ln[1], K)

lower_bounds!(opt, zeros(K))
upper_bounds!(opt, ones(K))

#equality_constraint!(opt, gradify(w->sum(w)-1, K))

max_objective!(opt, obj2)
#max_objective!(opt, (w,g) -> o(w) - ((sum(w)-1)*10000)^20)


maxeval!(opt, 10)

w=ones(K)/K

for i=1:2
  @time v,w = optimize!(opt, w) 
  @show v
end
#@show sum(w)
v
# Out:
#  44.480124 seconds (14.15 k allocations: 275.877 MB, 0.23% gc time)
# v = 0.16976308716301375
#  44.924617 seconds (13.14 k allocations: 275.822 MB, 0.21% gc time)
# v = 0.17015640156691667
# 0.17015640156691667

# %%
w
# Out:
# 900-element Array{Float64,1}:
#  0.00319571
#  0.0711636
#  0.789389
#  0.487174
#  0.00768181
#  0.392783
#  0.480511
#  0.774093
#  0.86932
#  0.214873
#  0.00287461
#  0.883961
#  0.684087
#  ⋮
#  0.747507
#  0.940556
#  0.795559
#  0.860478
#  0.822997
#  0.998803
#  0.924359
#  0.486064
#  0.465207
#  0.564916
#  0.394138
#  0.761875

# %%
using KernelDensity
using Plots
k=   kde(x[:,8], weights=w, bandwidth=0.1)
kuni=kde(x[:,8], bandwidth=0.1)
plot()
for k in [k, kuni]
    plot!(k.x, k.density)
end
plot!()
# Out:
# <img src="data:image/png;base64,..." />
